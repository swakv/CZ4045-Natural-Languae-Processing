# %% [markdown]
# ## 3.1 Domain Specific Dataset Analysis

# %% [markdown]
# ### Domain 2 - Medical Research Papers

# %% [markdown]
# #### Import necessary libraries

# %%
import nltk 
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer

# %% [markdown]
# #### Read in 20 documents from .txt files located in the specified directory and store them into a DataFrame

# %%
#read all medical research papers
#store one in each row in a column called "data"
file_path = 'domain2_data'
all_files = os.listdir(file_path)  

data = []
for file_name in all_files:
    this_file = open(os.path.join(file_path, file_name), encoding='utf8', errors='ignore')
    file_content = this_file.read()
    data.append([file_content]) 

df = pd.DataFrame(data, columns=['data'])
# df['data'].apply(lambda x: x.decode("utf-8"))
df = df.drop([0]).reset_index(drop=True)
df
# Out:
#                                                  data
# 0   (19) United States\n(12) Patent Application Pu...
# \n...
# 2   US010761497B2\n( 12 ) United States Patent ( 1...
# 3   (12) United States Patent\nJung et al.\nUSOO94...
# 4   (19) United States\nUS 20160096318A1\n(12) Pat...
# 5   US010232603B2\n( 12 ) United States Patent\nHa...
# 6   (19) United States\n(12) Patent Application Pu...
# 7   OUT\nUS M ANTAL 20170297262A1 UNUI MINUTI\n( 1...
# 8   | HAO WALA NAMAN UTAMAN US010016929B2 MINIAI M...
# 9   MAI MULT A MINHA CU CEI MAI MULT MAIN HATI US0...
# 10  US009314970B2\n(12) United States Patent (10) ...
# 11  US010730232B2\nUnited States Patent\nGuillemet...
# 12  THIR UTTU US009950465B2 MUUTTAMALLITTUR\n( 12 ...
# 13  (19) United States\nUS 20170050389A1\n(12) Pat...
# 14  US 20150375451A1\n(19) United States\n(12) Pat...
# 15  United States Patent\nUSOO9688024B2\n(12) (10)...
# 16  US010394202B2\n( 12 ) United States Patent\nMi...
# 17  US010507592B2\n( 12 ) United States Patent ( 1...
# 18  THE MAIN TEA ETA ANTON A MA MA EI MAI MO NA US...
# 19  (19) United States\n(12) Patent Application Pu...

# %% [markdown]
# #### Perform Tokenization using NLTK word_tokenize - splits strings into tokens (nominally words). It splits tokens based on white space and punctuation.

# %%
#tokenise each document and store in a new column called "tokens"
df['tokens'] = df.apply(lambda row : word_tokenize(row['data']), axis = 1)
df
# Out:
#                                                  data  \
# 0   (19) United States\n(12) Patent Application Pu...
# \n...
# 2   US010761497B2\n( 12 ) United States Patent ( 1...
# 3   (12) United States Patent\nJung et al.\nUSOO94...
# 4   (19) United States\nUS 20160096318A1\n(12) Pat...
# 5   US010232603B2\n( 12 ) United States Patent\nHa...
# 6   (19) United States\n(12) Patent Application Pu...
# 7   OUT\nUS M ANTAL 20170297262A1 UNUI MINUTI\n( 1...
# 8   | HAO WALA NAMAN UTAMAN US010016929B2 MINIAI M...
# 9   MAI MULT A MINHA CU CEI MAI MULT MAIN HATI US0...
# 10  US009314970B2\n(12) United States Patent (10) ...
# 11  US010730232B2\nUnited States Patent\nGuillemet...
# 12  THIR UTTU US009950465B2 MUUTTAMALLITTUR\n( 12 ...
# 13  (19) United States\nUS 20170050389A1\n(12) Pat...
# 14  US 20150375451A1\n(19) United States\n(12) Pat...
# 15  United States Patent\nUSOO9688024B2\n(12) (10)...
# 16  US010394202B2\n( 12 ) United States Patent\nMi...
# 17  US010507592B2\n( 12 ) United States Patent ( 1...
# 18  THE MAIN TEA ETA ANTON A MA MA EI MAI MO NA US...
# 19  (19) United States\n(12) Patent Application Pu...
#
#                                                tokens
# 0   [(, 19, ), United, States, (, 12, ), Patent, A...
# , ...
# 2   [US010761497B2, (, 12, ), United, States, Pate...
# 3   [(, 12, ), United, States, Patent, Jung, et, a...
# 4   [(, 19, ), United, States, US, 20160096318A1, ...
# 5   [US010232603B2, (, 12, ), United, States, Pate...
# 6   [(, 19, ), United, States, (, 12, ), Patent, A...
# 7   [OUT, US, M, ANTAL, 20170297262A1, UNUI, MINUT...
# 8   [|, HAO, WALA, NAMAN, UTAMAN, US010016929B2, M...
# 9   [MAI, MULT, A, MINHA, CU, CEI, MAI, MULT, MAIN...
# 10  [US009314970B2, (, 12, ), United, States, Pate...
# 11  [US010730232B2, United, States, Patent, Guille...
# 12  [THIR, UTTU, US009950465B2, MUUTTAMALLITTUR, (...
# 13  [(, 19, ), United, States, US, 20170050389A1, ...
# 14  [US, 20150375451A1, (, 19, ), United, States, ...
# 15  [United, States, Patent, USOO9688024B2, (, 12,...
# 16  [US010394202B2, (, 12, ), United, States, Pate...
# 17  [US010507592B2, (, 12, ), United, States, Pate...
# 18  [THE, MAIN, TEA, ETA, ANTON, A, MA, MA, EI, MA...
# 19  [(, 19, ), United, States, (, 12, ), Patent, A...

# %%
#write back into csv for future reference
# df.to_csv(os.path.join(file_path, 'tokens.csv'), index=False)

# %% [markdown]
# #### The token distributions before stemming is shown below

# %%
len_dict = {}
for index, row in df.iterrows():
    for token in row['tokens']:
        tlen = len(token)
        if tlen in len_dict.keys():
            len_dict[tlen]+=1
        else:
            len_dict[tlen]=1
            
len_dict = dict(sorted(len_dict.items()))
all_len = list(len_dict.keys())
num_tokens = list(len_dict.values())
plt.plot(all_len, num_tokens)
plt.xlabel('Token Lengths')
plt.xlim(0,28)
plt.xticks(np.arange(0, 28, 2))
plt.ylabel('Number of Tokens')
plt.show()

# %% [markdown]
# #### Perform Stemming using PorterStemmer. The Porter stemming algorithm is a process for removing the commoner morphological and inflexional endings from words in English.

# %%
stemming = PorterStemmer()
stemmed = []
df['stemmed'] = ""
for index,row in df.iterrows(): 
    stem_each = []
    for token in row['tokens']:
        stem_each.append(stemming.stem(token))
        df['stemmed'][index] = stem_each
    stemmed.append(stem_each)

df
# Out:
#                                                  data  \
# 0   (19) United States\n(12) Patent Application Pu...
# \n...
# 2   US010761497B2\n( 12 ) United States Patent ( 1...
# 3   (12) United States Patent\nJung et al.\nUSOO94...
# 4   (19) United States\nUS 20160096318A1\n(12) Pat...
# 5   US010232603B2\n( 12 ) United States Patent\nHa...
# 6   (19) United States\n(12) Patent Application Pu...
# 7   OUT\nUS M ANTAL 20170297262A1 UNUI MINUTI\n( 1...
# 8   | HAO WALA NAMAN UTAMAN US010016929B2 MINIAI M...
# 9   MAI MULT A MINHA CU CEI MAI MULT MAIN HATI US0...
# 10  US009314970B2\n(12) United States Patent (10) ...
# 11  US010730232B2\nUnited States Patent\nGuillemet...
# 12  THIR UTTU US009950465B2 MUUTTAMALLITTUR\n( 12 ...
# 13  (19) United States\nUS 20170050389A1\n(12) Pat...
# 14  US 20150375451A1\n(19) United States\n(12) Pat...
# 15  United States Patent\nUSOO9688024B2\n(12) (10)...
# 16  US010394202B2\n( 12 ) United States Patent\nMi...
# 17  US010507592B2\n( 12 ) United States Patent ( 1...
# 18  THE MAIN TEA ETA ANTON A MA MA EI MAI MO NA US...
# 19  (19) United States\n(12) Patent Application Pu...
#
#                                                tokens  \
# 0   [(, 19, ), United, States, (, 12, ), Patent, A...
# , ...
# 2   [US010761497B2, (, 12, ), United, States, Pate...
# 3   [(, 12, ), United, States, Patent, Jung, et, a...
# 4   [(, 19, ), United, States, US, 20160096318A1, ...
# 5   [US010232603B2, (, 12, ), United, States, Pate...
# 6   [(, 19, ), United, States, (, 12, ), Patent, A...
# 7   [OUT, US, M, ANTAL, 20170297262A1, UNUI, MINUT...
# 8   [|, HAO, WALA, NAMAN, UTAMAN, US010016929B2, M...
# 9   [MAI, MULT, A, MINHA, CU, CEI, MAI, MULT, MAIN...
# 10  [US009314970B2, (, 12, ), United, States, Pate...
# 11  [US010730232B2, United, States, Patent, Guille...
# 12  [THIR, UTTU, US009950465B2, MUUTTAMALLITTUR, (...
# 13  [(, 19, ), United, States, US, 20170050389A1, ...
# 14  [US, 20150375451A1, (, 19, ), United, States, ...
# 15  [United, States, Patent, USOO9688024B2, (, 12,...
# 16  [US010394202B2, (, 12, ), United, States, Pate...
# 17  [US010507592B2, (, 12, ), United, States, Pate...
# 18  [THE, MAIN, TEA, ETA, ANTON, A, MA, MA, EI, MA...
# 19  [(, 19, ), United, States, (, 12, ), Patent, A...
#
#                                               stemmed
# 0   [(, 19, ), unit, state, (, 12, ), patent, appl...
# , ...
# 2   [us010761497b2, (, 12, ), unit, state, patent,...
# 3   [(, 12, ), unit, state, patent, jung, et, al, ...
# 4   [(, 19, ), unit, state, US, 20160096318a1, (, ...
# 5   [us010232603b2, (, 12, ), unit, state, patent,...
# 6   [(, 19, ), unit, state, (, 12, ), patent, appl...
# 7   [out, US, M, antal, 20170297262a1, unui, minut...
# 8   [|, hao, wala, naman, utaman, us010016929b2, m...
# 9   [mai, mult, A, minha, CU, cei, mai, mult, main...
# 10  [us009314970b2, (, 12, ), unit, state, patent,...
# 11  [us010730232b2, unit, state, patent, guillemet...
# 12  [thir, uttu, us009950465b2, muuttamallittur, (...
# 13  [(, 19, ), unit, state, US, 20170050389a1, (, ...
# 14  [US, 20150375451a1, (, 19, ), unit, state, (, ...
# 15  [unit, state, patent, usoo9688024b2, (, 12, ),...
# 16  [us010394202b2, (, 12, ), unit, state, patent,...
# 17  [us010507592b2, (, 12, ), unit, state, patent,...
# 18  [the, main, tea, eta, anton, A, MA, MA, EI, ma...
# 19  [(, 19, ), unit, state, (, 12, ), patent, appl...

# %%
#write back into csv for future reference
# df.to_csv(os.path.join(file_path, 'stems.csv'), index=False)

# %% [markdown]
# #### The token distribution after stemming is shown below

# %%
len_dict = {}
for index, row in df.iterrows():
    for token in row['stemmed']:
        tlen = len(token)
        if tlen in len_dict.keys():
            len_dict[tlen]+=1
        else:
            len_dict[tlen]=1

len_dict = dict(sorted(len_dict.items()))
all_len = list(len_dict.keys())
num_tokens = list(len_dict.values())
plt.plot(all_len, num_tokens)
plt.xlabel('Stem Lengths')
plt.xlim(0,16)
plt.xticks(np.arange(0, 16, 2))
plt.ylabel('Number of Tokens')
plt.show()

# %% [markdown]
# #### Dataframe after Tokenization, Stemming and Sentence Segmentation
# #### Sentence segmentation is done using sent_tokenize from NLTK. The sent_tokenize function uses an instance of PunktSentenceTokenizer from the nltk. The punkt module, has already been trained and can mark the end and beginning of sentence at  characters and punctuation.

# %%
df['sentences'] = df.apply(lambda row : sent_tokenize(row['data']), axis = 1)
df
# Out:
#                                                  data  \
# 0   (19) United States\n(12) Patent Application Pu...
# \n...
# 2   US010761497B2\n( 12 ) United States Patent ( 1...
# 3   (12) United States Patent\nJung et al.\nUSOO94...
# 4   (19) United States\nUS 20160096318A1\n(12) Pat...
# 5   US010232603B2\n( 12 ) United States Patent\nHa...
# 6   (19) United States\n(12) Patent Application Pu...
# 7   OUT\nUS M ANTAL 20170297262A1 UNUI MINUTI\n( 1...
# 8   | HAO WALA NAMAN UTAMAN US010016929B2 MINIAI M...
# 9   MAI MULT A MINHA CU CEI MAI MULT MAIN HATI US0...
# 10  US009314970B2\n(12) United States Patent (10) ...
# 11  US010730232B2\nUnited States Patent\nGuillemet...
# 12  THIR UTTU US009950465B2 MUUTTAMALLITTUR\n( 12 ...
# 13  (19) United States\nUS 20170050389A1\n(12) Pat...
# 14  US 20150375451A1\n(19) United States\n(12) Pat...
# 15  United States Patent\nUSOO9688024B2\n(12) (10)...
# 16  US010394202B2\n( 12 ) United States Patent\nMi...
# 17  US010507592B2\n( 12 ) United States Patent ( 1...
# 18  THE MAIN TEA ETA ANTON A MA MA EI MAI MO NA US...
# 19  (19) United States\n(12) Patent Application Pu...
#
#                                                tokens  \
# 0   [(, 19, ), United, States, (, 12, ), Patent, A...
# , ...
# 2   [US010761497B2, (, 12, ), United, States, Pate...
# 3   [(, 12, ), United, States, Patent, Jung, et, a...
# 4   [(, 19, ), United, States, US, 20160096318A1, ...
# 5   [US010232603B2, (, 12, ), United, States, Pate...
# 6   [(, 19, ), United, States, (, 12, ), Patent, A...
# 7   [OUT, US, M, ANTAL, 20170297262A1, UNUI, MINUT...
# 8   [|, HAO, WALA, NAMAN, UTAMAN, US010016929B2, M...
# 9   [MAI, MULT, A, MINHA, CU, CEI, MAI, MULT, MAIN...
# 10  [US009314970B2, (, 12, ), United, States, Pate...
# 11  [US010730232B2, United, States, Patent, Guille...
# 12  [THIR, UTTU, US009950465B2, MUUTTAMALLITTUR, (...
# 13  [(, 19, ), United, States, US, 20170050389A1, ...
# 14  [US, 20150375451A1, (, 19, ), United, States, ...
# 15  [United, States, Patent, USOO9688024B2, (, 12,...
# 16  [US010394202B2, (, 12, ), United, States, Pate...
# 17  [US010507592B2, (, 12, ), United, States, Pate...
# 18  [THE, MAIN, TEA, ETA, ANTON, A, MA, MA, EI, MA...
# 19  [(, 19, ), United, States, (, 12, ), Patent, A...
#
#                                               stemmed  \
# 0   [(, 19, ), unit, state, (, 12, ), patent, appl...
# , ...
# 2   [us010761497b2, (, 12, ), unit, state, patent,...
# 3   [(, 12, ), unit, state, patent, jung, et, al, ...
# 4   [(, 19, ), unit, state, US, 20160096318a1, (, ...
# 5   [us010232603b2, (, 12, ), unit, state, patent,...
# 6   [(, 19, ), unit, state, (, 12, ), patent, appl...
# 7   [out, US, M, antal, 20170297262a1, unui, minut...
# 8   [|, hao, wala, naman, utaman, us010016929b2, m...
# 9   [mai, mult, A, minha, CU, cei, mai, mult, main...
# 10  [us009314970b2, (, 12, ), unit, state, patent,...
# 11  [us010730232b2, unit, state, patent, guillemet...
# 12  [thir, uttu, us009950465b2, muuttamallittur, (...
# 13  [(, 19, ), unit, state, US, 20170050389a1, (, ...
# 14  [US, 20150375451a1, (, 19, ), unit, state, (, ...
# 15  [unit, state, patent, usoo9688024b2, (, 12, ),...
# 16  [us010394202b2, (, 12, ), unit, state, patent,...
# 17  [us010507592b2, (, 12, ), unit, state, patent,...
# 18  [the, main, tea, eta, anton, A, MA, MA, EI, ma...
# 19  [(, 19, ), unit, state, (, 12, ), patent, appl...
#
#                                             sentences
# 0   [(19) United States\n(12) Patent Application P...
# \n...
# 2   [US010761497B2\n( 12 ) United States Patent ( ...
# 3   [(12) United States Patent\nJung et al., USOO9...
# 4   [(19) United States\nUS 20160096318A1\n(12) Pa...
# 5   [US010232603B2\n( 12 ) United States Patent\nH...
# 6   [(19) United States\n(12) Patent Application P...
# 7   [OUT\nUS M ANTAL 20170297262A1 UNUI MINUTI\n( ...
# 8   [| HAO WALA NAMAN UTAMAN US010016929B2 MINIAI ...
# 9   [MAI MULT A MINHA CU CEI MAI MULT MAIN HATI US...
# 10  [US009314970B2\n(12) United States Patent (10)...
# 11  [US010730232B2\nUnited States Patent\nGuilleme...
# 12  [THIR UTTU US009950465B2 MUUTTAMALLITTUR\n( 12...
# 13  [(19) United States\nUS 20170050389A1\n(12) Pa...
# 14  [US 20150375451A1\n(19) United States\n(12) Pa...
# 15  [United States Patent\nUSOO9688024B2\n(12) (10...
# 16  [US010394202B2\n( 12 ) United States Patent\nM...
# 17  [US010507592B2\n( 12 ) United States Patent ( ...
# 18  [THE MAIN TEA ETA ANTON A MA MA EI MAI MO NA U...
# 19  [(19) United States\n(12) Patent Application P...

# %%
# df.to_csv('stemmed_data.csv', index=False)

# %%
df['sentences'] = df.apply(lambda row : sent_tokenize(row['data']), axis = 1)
# df.to_csv('sentences.csv', index=False)

# %% [markdown]
# #### Distribution of the sentence lengths across this domain is shown below

# %%
len_dict = {}
for index, row in df.iterrows():
    for sentence in row['sentences']:
        x = word_tokenize(sentence)
        len_this_sent = len(x)
        if len_this_sent in len_dict.keys():
            len_dict[len_this_sent]+=1
        else:
            len_dict[len_this_sent]=1

len_dict = dict(sorted(len_dict.items()))
all_len = list(len_dict.keys())
num_tokens = list(len_dict.values())
plt.plot(all_len, num_tokens)
plt.xlabel('Sentence Lengths')
plt.xlim(0,40)
plt.xticks(np.arange(0, 40, 5))
# plt.yticks(np.arange(0, 5, 1))
plt.ylabel('Number of Sentences')
plt.show()

# %% [markdown]
# #### Choose 3 sentences for POS tagging

# %%
sentences = ["These drawbacks of local delivery methods could be addressed by employing a systemic delivery route, such as intravenous injection, since the lower region of the lung is directly accessible through capillary blood vessels surrounding the alveoli, circumventing the interference of pulmonary surfactants. However, systemic delivery of oligonucleotide therapeutics into the fibrotic region of the lung is very challenging, as it requires a delivery platform that can achieve multiple goals, including protection of oligonucleotides against nuclease, lung-specific distribution of the oligonucleotides, and intracellular delivery of the distributed oligonucleotides into the fibrotic cells.", "The completed reaction solution was added to prewashed HaloLink resin for HaloTEV removal.", "Results indicate that magnetite component of magnetic uids is important for inhibiting activity; however, the MF physical properties together with character of NP coating determine the extent of inhibition."]
# Out:
# /Library/Python/3.7/site-packages/IPython/core/inputtransformer2.py:481: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")

# %% [markdown]
# #### Implement POS tagging using NLTK's pos_tag() function

# %%
pos_result = []
for i in range(0,3):
    text = word_tokenize(sentences[i])
    pos_temp = nltk.pos_tag(text)
    pos_result.append(pos_temp)
pos_result
# Out:
# [[('These', 'DT'),
#   ('drawbacks', 'NNS'),
#   ('of', 'IN'),
#   ('local', 'JJ'),
#   ('delivery', 'NN'),
#   ('methods', 'NNS'),
#   ('could', 'MD'),
#   ('be', 'VB'),
#   ('addressed', 'VBN'),
#   ('by', 'IN'),
#   ('employing', 'VBG'),
#   ('a', 'DT'),
#   ('systemic', 'JJ'),
#   ('delivery', 'NN'),
#   ('route', 'NN'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('intravenous', 'JJ'),
#   ('injection', 'NN'),
#   (',', ','),
#   ('since', 'IN'),
#   ('the', 'DT'),
#   ('lower', 'JJR'),
#   ('region', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('lung', 'NN'),
#   ('is', 'VBZ'),
#   ('directly', 'RB'),
#   ('accessible', 'JJ'),
#   ('through', 'IN'),
#   ('capillary', 'JJ'),
#   ('blood', 'NN'),
#   ('vessels', 'NNS'),
#   ('surrounding', 'VBG'),
#   ('the', 'DT'),
#   ('alveoli', 'NN'),
#   (',', ','),
#   ('circumventing', 'VBG'),
#   ('the', 'DT'),
#   ('interference', 'NN'),
#   ('of', 'IN'),
#   ('pulmonary', 'JJ'),
#   ('surfactants', 'NNS'),
#   ('.', '.'),
#   ('However', 'RB'),
#   (',', ','),
#   ('systemic', 'JJ'),
#   ('delivery', 'NN'),
#   ('of', 'IN'),
#   ('oligonucleotide', 'JJ'),
#   ('therapeutics', 'NNS'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('fibrotic', 'JJ'),
#   ('region', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('lung', 'NN'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('challenging', 'JJ'),
#   (',', ','),
#   ('as', 'IN'),
#   ('it', 'PRP'),
#   ('requires', 'VBZ'),
#   ('a', 'DT'),
#   ('delivery', 'NN'),
#   ('platform', 'NN'),
#   ('that', 'WDT'),
#   ('can', 'MD'),
#   ('achieve', 'VB'),
#   ('multiple', 'JJ'),
#   ('goals', 'NNS'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('protection', 'NN'),
#   ('of', 'IN'),
#   ('oligonucleotides', 'NNS'),
#   ('against', 'IN'),
#   ('nuclease', 'NN'),
#   (',', ','),
#   ('lung-specific', 'JJ'),
#   ('distribution', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('oligonucleotides', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('intracellular', 'JJ'),
#   ('delivery', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('distributed', 'JJ'),
#   ('oligonucleotides', 'NNS'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('fibrotic', 'JJ'),
#   ('cells', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('completed', 'VBN'),
#   ('reaction', 'NN'),
#   ('solution', 'NN'),
#   ('was', 'VBD'),
#   ('added', 'VBN'),
#   ('to', 'TO'),
#   ('prewashed', 'VB'),
#   ('HaloLink', 'NNP'),
#   ('resin', 'NN'),
#   ('for', 'IN'),
#   ('HaloTEV', 'NNP'),
#   ('removal', 'NN'),
#   ('.', '.')],
#  [('Results', 'NNS'),
#   ('indicate', 'VBP'),
#   ('that', 'IN'),
#   ('magnetite', 'JJ'),
#   ('component', 'NN'),
#   ('of', 'IN'),
#   ('magnetic', 'JJ'),
#   ('uids', 'NNS'),
#   ('is', 'VBZ'),
#   ('important', 'JJ'),
#   ('for', 'IN'),
#   ('inhibiting', 'VBG'),
#   ('activity', 'NN'),
#   (';', ':'),
#   ('however', 'RB'),
#   (',', ','),
#   ('the', 'DT'),
#   ('MF', 'NNP'),
#   ('physical', 'JJ'),
#   ('properties', 'NNS'),
#   ('together', 'RB'),
#   ('with', 'IN'),
#   ('character', 'NN'),
#   ('of', 'IN'),
#   ('NP', 'NNP'),
#   ('coating', 'VBG'),
#   ('determine', 'VB'),
#   ('the', 'DT'),
#   ('extent', 'NN'),
#   ('of', 'IN'),
#   ('inhibition', 'NN'),
#   ('.', '.')]]
